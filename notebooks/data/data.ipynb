# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib as mpl
import folium
from downloader import DownloadInfo
from sentinelhub import bbox_to_dimensions, BBox, CRS
import sklearn.cluster as skc
from sklearn.preprocessing import StandardScaler

# %load_ext autoreload
# %autoreload 2

mpl.rcParams['figure.dpi'] = 150
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
excel_df = pd.read_excel("converted_data.xlsx")

# %%
df = gpd.GeoDataFrame(
    excel_df, geometry=gpd.points_from_xy(excel_df["Northing"], excel_df["Easting"]), crs="EPSG:4326"
)
df.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
new_df = df.to_crs(epsg=3348)
new_df.crs
# Out:
# <Projected CRS: EPSG:3348>
# Name: NAD83(CSRS) / Statistics Canada Lambert
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Canada - onshore and offshore - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon.
# - bounds: (-141.01, 38.21, -40.73, 86.46)
# Coordinate Operation:
# - name: Statistics Canada Lambert
# - method: Lambert Conic Conformal (2SP)
# Datum: NAD83 Canadian Spatial Reference System
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
polygon = gpd.GeoDataFrame(index=[0], crs=new_df.crs, geometry = [new_df.unary_union.convex_hull.buffer(1_000)])
polygon = polygon.to_crs(df.crs)

polygon.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e15a13bf7a42d9b02993f0f17e30d28e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e15a13bf7a42d9b02993f0f17e30d28e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e15a13bf7a42d9b02993f0f17e30d28e = L.map(
#                 &quot;map_e15a13bf7a42d9b02993f0f17e30d28e&quot;,
#                 {
#                     center: [56.80542785754687, -111.61273460276391],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e15a13bf7a42d9b02993f0f17e30d28e);
#
#
#
#
#
#             var tile_layer_8a2db0a781d2886c722902131223f286 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e15a13bf7a42d9b02993f0f17e30d28e);
#
#
#             map_e15a13bf7a42d9b02993f0f17e30d28e.fitBounds(
#                 [[56.465655890322424, -111.93925955074637], [57.14519982477131, -111.28620965478146]],
#                 {}
#             );
#
#
#         function geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3 = L.geoJson(null, {
#                 onEachFeature: geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_onEachFeature,
#
#                 style: geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_styler,
#                 pointToLayer: geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_pointToLayer
#         });
#
#         function geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_add (data) {
#             geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3
#                 .addData(data)
#                 .addTo(map_e15a13bf7a42d9b02993f0f17e30d28e);
#         }
#             geo_json_b6f5edc67aad2d355deaaf9d4ee74ed3_add({&quot;bbox&quot;: [-111.93925955074637, 56.465655890322424, -111.28620965478146, 57.14519982477131], &quot;features&quot;: [{&quot;bbox&quot;: [-111.93925955074637, 56.465655890322424, -111.28620965478146, 57.14519982477131], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-111.28620965478146, 56.475267053433214], [-111.28621529595196, 56.47435062219753], [-111.28638591284404, 56.473439065152576], [-111.28671979438052, 56.47254145615214], [-111.28721360494299, 56.47166672947413], [-111.28786241804646, 56.47082359093877], [-111.28865976580202, 56.470020431327306], [-111.2895977036582, 56.46926524295977], [-111.29066688976262,

# %%
minx, miny, maxx, maxy = polygon.bounds["minx"][0], polygon.bounds["miny"][0], polygon.bounds["maxx"][0],polygon.bounds["maxy"][0]

m = folium.Map([maxy, maxx])

folium.Rectangle([[miny, minx], [maxy, maxx]], popup="Expanded bbox", color="blue", fill=True, fillopacity=0.2).add_to(m)

minx, miny, maxx, maxy = df.total_bounds[0], df.total_bounds[1], df.total_bounds[2], df.total_bounds[3]

folium.Rectangle([[miny, minx], [maxy, maxx]], popup="Original bbox", color="red", fill=True, fillopacity=0.2).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41ee38c0d574e750d137318ba113830b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41ee38c0d574e750d137318ba113830b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41ee38c0d574e750d137318ba113830b = L.map(
#                 &quot;map_41ee38c0d574e750d137318ba113830b&quot;,
#                 {
#                     center: [57.14519982477131, -111.28620965478146],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d1532101a2c9e4ffc09ad0c77d62cad = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_41ee38c0d574e750d137318ba113830b);
#
#
#             var rectangle_90d509051fd739bdc4fc6846da5f8de8 = L.rectangle(
#                 [[56.465655890322424, -111.93925955074637], [57.14519982477131, -111.28620965478146]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_41ee38c0d574e750d137318ba113830b);
#
#
#         var popup_26fe99f44c11322cfc6c573152022b7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_530c4f71800786154878384bbe881c16 = $(`&lt;div id=&quot;html_530c4f71800786154878384bbe881c16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Expanded bbox&lt;/div&gt;`)[0];
#                 popup_26fe99f44c11322cfc6c573152022b7d.setContent(html_530c4f71800786154878384bbe881c16);
#
#
#
#         rectangle_90d509051fd739bdc4fc6846da5f8de8.bindPopup(popup_26fe99f44c11322cfc6c573152022b7d)
#         ;
#
#
#
#
#             var rectangle_4201c468ceaf94471d226d59802c7bf0 = L.rectangle(
#                 [[56.4748388941366, -111.922424427123], [57.1360039915042, -111.302787981802]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_41ee38c0d574e750d137318ba113830b);
#
#
#         var popup_fd28280e2a12291e5f5afc76e3565c26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61ede05c1aad1ede0476d210902ae8da = $(`&lt;div id=&quot;html_61ede05c1aad1ede0476d210902ae8da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Original bbox&lt;/div&gt;`)[0];
#                 popup_fd28280e2a12291e5f5afc76e3565c26.setContent(html_61ede05c1aad1ede0476d210902ae8da);
#
#
#
#         rectangle_4201c468ceaf94471d226d59802c7bf0.bindPopup(popup_fd28280e2a12291e5f5afc76e3565c26)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Cluster wetlands that are close to each other

coordinates = new_df["geometry"].apply(lambda p: np.hstack(p.xy)).values
coordinates = np.vstack(coordinates)

# %%
scalar = StandardScaler()
scaled_features = scalar.fit_transform(coordinates)

def cluster(n_clusters):
    """Returns the dataframes, the bboxs, and then the k-means result (in that order)"""
    test_dfs = []
    bboxs = []
    kmeans = skc.KMeans(init="random", n_clusters=n_clusters, n_init=10)
    kmeans.fit(scaled_features)

    bboxs = []
    for i in range(n_clusters):
        matching_wetlands = []
        for j, wetland in new_df.iterrows():
            if kmeans.labels_[j] == i:
                matching_wetlands.append(wetland.geometry)
        test_geometry = gpd.GeoDataFrame(geometry=matching_wetlands, crs=new_df.crs).unary_union.convex_hull.buffer(1_000)
        test_df = gpd.GeoDataFrame(geometry = [test_geometry], crs=new_df.crs)
        test_df.to_crs(df.crs, inplace=True)
        bbox = BBox([test_df.bounds.minx.values[0], test_df.bounds.miny.values[0], test_df.bounds.maxx.values[0], test_df.bounds.maxy.values[0]], crs=CRS.WGS84)
        dimensions = bbox_to_dimensions(bbox, 10)
        if dimensions[0] > 2500 or dimensions[1] > 2500:
            print("dimensions are too big:", dimensions)
            return cluster(n_clusters + 1)
        else:
            bboxs.append(bbox)
            test_dfs.append(test_df)
    
    return test_dfs, bboxs, kmeans

result = cluster(3)
result[0]
# Out:
# dimensions are too big: (1228, 3711)
# [                                            geometry
#  0  POLYGON ((-111.71544 56.94102, -111.71627 56.9...,
#                                              geometry
#  0  POLYGON ((-111.33781 56.66411, -111.33746 56.6...,
#                                              geometry
#  0  POLYGON ((-111.56362 56.94382, -111.56508 56.9...,
#                                              geometry
#  0  POLYGON ((-111.28621 56.47527, -111.28622 56.4...]

# %%
download = DownloadInfo(result[1][0], 2019, 2019)
download.download()
# Out:
# This method will likely take a very long time to run
# [1][11:33:02.739011] Data fetched for date 2019-05-17
# [2][11:33:08.035382] Data fetched for date 2019-09-08
# [3][11:33:13.564371] Data fetched for date 2019-06-22
# [4][11:33:18.632838] Data fetched for date 2019-12-06
# [5][11:33:23.970735] Data fetched for date 2019-06-04
# [6][11:33:29.027749] Data fetched for date 2019-09-01
# [7][11:33:34.238014] Data fetched for date 2019-12-01
# [8][11:33:39.359544] Data fetched for date 2019-09-14
# [9][11:33:44.272953] Data fetched for date 2019-01-16
# [10][11:33:49.397405] Data fetched for date 2019-12-25
# [11][11:33:55.950089] Data fetched for date 2019-03-12
# [12][11:34:02.308458] Data fetched for date 2019-07-04
# [13][11:34:07.413260] Data fetched for date 2019-10-02
# [14][11:34:13.581706] Data fetched for date 2019-03-24
# [15][11:34:18.870133] Data fetched for date 2019-03-17
# [16][11:34:23.737806] Data fetched for date 2019-08-27
# [17][11:34:40.063493] Data fetched for date 2019-05-23
# [18][11:34:47.970679] Data fetched for date 2019-06-28
# [19][11:34:56.368484] Data fetched for date 2019-05-29
# [20][11:35:04.043959] Data fetched for date 2019-04-17
# [21][11:35:09.452892] Data fetched for date 2019-11-07
# [22][11:35:15.649205] Data fetched for date 2019-08-08
# [23][11:35:21.959629] Data fetched for date 2019-08-20
# [24][11:35:27.560369] Data fetched for date 2019-11-12
# [25][11:35:35.864799] Data fetched for date 2019-08-21
# [26][11:35:41.003856] Data fetched for date 2019-04-22
# [27][11:35:46.354555] Data fetched for date 2019-01-04
# [28][11:35:54.518709] Data fetched for date 2019-08-09
# [29][11:36:00.743348] Data fetched for date 2019-05-16
# [30][11:36:06.620700] Data fetched for date 2019-10-20
# [31][11:36:12.552844] Data fetched for date 2019-01-23
# [32][11:36:17.897861] Data fetched for date 2019-09-13
# [33][11:36:24.848790] Data fetched for date 2019-10-08
# [34][11:36:30.301933] Data fetched for date 2019-03-05
# [35][11:36:35.700675] Data fetched for date 2019-07-16
# [36][11:36:42.041345] Data fetched for date 2019-09-02
# [37][11:36:47.782142] Data fetched for date 2019-07-03
# [38][11:36:54.344101] Data fetched for date 2019-10-26
# [39][11:36:59.867793] Data fetched for date 2019-10-14
# [40][11:37:05.286625] Data fetched for date 2019-02-16
# [41][11:37:13.175285] Data fetched for date 2019-08-03
# [42][11:37:18.685895] Data fetched for date 2019-04-05
# [43][11:37:25.243133] Data fetched for date 2019-07-10
# [44][11:37:31.202477] Data fetched for date 2019-12-18
# [45][11:37:38.745072] Data fetched for date 2019-07-22
# [46][11:37:45.949512] Data fetched for date 2019-04-10
# [47][11:37:52.499569] Data fetched for date 2019-05-04
# [48][11:37:58.243453] Data fetched for date 2019-07-15
# [49][11:38:04.353472] Data fetched for date 2019-01-11
# [50][11:38:11.098028] Data fetched for date 2019-01-28
# [51][11:38:18.307369] Data fetched for date 2019-11-19
# [52][11:38:24.641996] Data fetched for date 2019-03-29
# [53][11:38:29.376024] Data fetched for date 2019-09-20
# [54][11:38:36.127245] Data fetched for date 2019-12-30
# [55][11:38:41.654596] Data fetched for date 2019-12-07
# [56][11:38:48.605539] Data fetched for date 2019-10-07
# [57][11:38:54.353742] Data fetched for date 2019-05-28
# [58][11:39:00.884698] Data fetched for date 2019-04-29
# [59][11:39:08.680841] Data fetched for date 2019-08-15
# [60][11:39:15.034409] Data fetched for date 2019-12-13
# [61][11:39:20.961866] Data fetched for date 2019-02-21
# [62][11:39:27.741733] Data fetched for date 2019-07-28
# [63][11:39:36.127184] Data fetched for date 2019-11-25
# [64][11:39:43.113528] Data fetched for date 2019-06-21
# [65][11:39:49.659351] Data fetched for date 2019-06-16
# [66][11:39:55.182492] Data fetched for date 2019-10-19
# [67][11:40:02.185567] Data fetched for date 2019-07-27
# [68][11:40:09.711416] Data fetched for date 2019-12-19
# [69][11:40:19.712734] Data fetched for date 2019-10-31
# [70][11:40:25.201943] Data fetched for date 2019-02-04
# [71][11:40:32.162160] Data fetched for date 2019-11-01
# [72][11:40:38.969351] Data fetched for date 2019-02-09
# [73][11:40:48.420790] Data fetched for date 2019-09-25
# [74][11:40:55.010323] Data fetched for date 2019-06-09
# [75][11:41:00.921079] Data fetched for date 2019-11-24
# [76][11:41:07.861265] Data fetched for date 2019-05-11
# [77][11:41:13.624597] Data fetched for date 2019-11-13
# [78][11:41:18.687638] Data fetched for date 2019-06-10
# [79][11:41:26.423718] Data fetched for date 2019-09-26

# %%
def get_color(i):
    if result[2].labels_[i] == 0:
        return "red"
    elif result[2].labels_[i] == 1:
        return "blue"
    elif result[2].labels_[i] == 2:
        return "green"
    elif result[2].labels_[i] == 3:
        return "purple"

m = folium.Map()

for i, wetland in df.iterrows():
    geometry = wetland["geometry"].xy
    folium.CircleMarker([geometry[1][0], geometry[0][0]], color=get_color(i), fill=True, fill_opacity=0.7, popup=wetland["Wetland"]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c17fabec9cab0f0a2e2beb4270c85357 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c17fabec9cab0f0a2e2beb4270c85357&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c17fabec9cab0f0a2e2beb4270c85357 = L.map(
#                 &quot;map_c17fabec9cab0f0a2e2beb4270c85357&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cc3808a2436a8ac75e8fb4abaf89daa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c17fabec9cab0f0a2e2beb4270c85357);
#
#
#             var circle_marker_273d09fe2a0462212d176e6e85533e07 = L.circleMarker(
#                 [57.036247, -111.530457],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c17fabec9cab0f0a2e2beb4270c85357);
#
#
#         var popup_d264445a7afd675b20186ccf1ed03cc7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08cd6bbf3bff1acfe9088bfba24d8667 = $(`&lt;div id=&quot;html_08cd6bbf3bff1acfe9088bfba24d8667&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;63 N 001&lt;/div&gt;`)[0];
#                 popup_d264445a7afd675b20186ccf1ed03cc7.setContent(html_08cd6bbf3bff1acfe9088bfba24d8667);
#
#
#
#         circle_marker_273d09fe2a0462212d176e6e85533e07.bindPopup(popup_d264445a7afd675b20186ccf1ed03cc7)
#         ;
#
#
#
#
#             var circle_marker_e2d8bca8edfa9259785f301b0e3a216f = L.circleMarker(
#                 [56.5452671071295, -111.31338460568],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c17fabec9cab0f0a2e2beb4270c85357);
#
#
#         var popup_2b9511eda8c43c64c69825ee48cc3068 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b65a76eabcc0babd8a78ff4babb458d = $(`&lt;div id=&quot;html_9b65a76eabcc0babd8a78ff4babb458d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;63 N 002&lt;/div&gt;`)[0];
#                 popup_2b9511eda8c43c64c69825ee48cc3068.setContent(html_9b65a76eabcc0babd8a78ff4babb458d);
#
#
#
#         circle_marker_e2d8bca8edfa9259785f301b0e3a216f.bindPopup(popup_2b9511eda8c43c64c69825ee48cc3068)
#         ;
#
#
#
#
#             var circle_marker_2c8b2de8baff9c8d7adde04ed44daac7 = L.circleMarker(
#                 [56.5630007432716, -111.310260648532],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c17fabec9cab0f0a2e2beb4270c85357);
#
#
#         var popup_6fb60271582e6ac356d080f25d82f7e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02029e26520ed5dd9f922d6d113544b9 = $(`&lt;div id=&quot;html_02029e26520ed5dd9f922d6d113544b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;63 N 003&lt;/div&gt;`)[0];
#                 popup_6fb60271582e6ac356d080f25d82f7e2.setContent(html_02029e26520ed5dd9f922d6d113544b9);
#
#
#
#         circle_marker_2c8b2de8baff9c8d7adde04ed44daac7.bindPopup(popup_6fb60271582e6ac356d080f25d82f7e2)
#         ;
#
#
#
#
#             var circle_marker_d19a059cf70a210ec0794c3869e89b52 = L.circleMarker(
#                 [56.5829677619513, -111.312166118228],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nu
